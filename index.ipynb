# %% [markdown]
# # Reading API Documentation
#
# We've now covered an example API request, but how on Earth would you know how to do that on your own? The answer is through documentation! All APIs will have associated documentation, and while there are substantial similarities, all will be different to one degree or another. The best way to get more comfortable is to practice! So with that, let's take a look at the yelp documentation associated with our previous example.
#
# Start by navigating to: https://www.yelp.com/developers/documentation/v3/get_started and having a look for yourself!
#
# <img src="yelp_overview.png">

# %% [markdown]
# As you see at the top, the first piece of almost every API is authentication. If you didn't already generate an access token in the previously lab go do so now.
#
# Go to https://www.yelp.com/developers/v3/manage_app and create a new app.
#
# <img src="yelp_app.png">

# %% [markdown]
# Let's take a closer look at Yelp's authentication documentation:
# https://www.yelp.com/developers/documentation/v3/authentication
#
# <img src="yelp_auth.png">

# %% [markdown]
# Notice in the documentation, it gives us the specific format "Put the API Key in the request header as "Authorization: Bearer <YOUR API KEY>"." This is what we passed in our get request.
# As a reminder, we have:

# %%
import requests

# %%
client_id = '4a1Th_CK66VwxOJRBiL9Ug'
api_key = 'JmcTQw4BEwAWkl2F0tsMtuRCxbcn02U6aiu-Yu7YXzuG12_NmoFhCtB894V63kOogr6aLNAt7sv6sGPCR9xDwa89-hGBZRlUMb3tk0bEuEIlvWg6v0Vf88bpGasRXHYx'
url = 'https://api.yelp.com/v3/businesses/search'
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

response = requests.get(url, headers=headers)

# %% [markdown]
#  With that, let's take a look at how the rest of our request should be formatted. Go to https://www.yelp.com/developers/documentation/v3/business_search  and take a couple minutes to look things over.
#
#  <img src="yelp_docs.png">

# %% [markdown]
# Notice the first part is the format of the get request! This is the url we pass into our get request. From there, the available parameters that you can pass are listed. These define your query, some are required while others are optional.

# %% [markdown]
# Reviewing our python package we thus have:

# %%
#Note: this cell won't return a valid response unless you specify your api key
import requests
client_id = '4a1Th_CK66VwxOJRBiL9Ug'
api_key = 'JmcTQw4BEwAWkl2F0tsMtuRCxbcn02U6aiu-Yu7YXzuG12_NmoFhCtB894V63kOogr6aLNAt7sv6sGPCR9xDwa89-hGBZRlUMb3tk0bEuEIlvWg6v0Vf88bpGasRXHYx'
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC'
            }
response = requests.get(url, headers=headers, params=url_params)
response.json()
# Out:
# {'businesses': [{'id': 'H4jJ7XB3CetIr1pg56CczQ',
#    'alias': 'levain-bakery-new-york',
#    'name': 'Levain Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qS--12qjadrrhQ--huKKuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/levain-bakery-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 7129,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7799404643263,
#     'longitude': -73.980282552649},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '167 W 74th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['167 W 74th St', 'New York, NY 10023']},
#    'phone': '+12128746080',
#    'display_phone': '(212) 874-6080',
#    'distance': 8367.197123060287},
#   {'id': 'xEnNFXtMLDF5kZDxfaCJgA',
#    'alias': 'the-halal-guys-new-york-2',
#    'name': 'The Halal Guys',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/24lb-VP2zVySsY9cq45ETw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-halal-guys-new-york-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 9064,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7617559582706,
#     'longitude': -73.979229927063},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'W 53rd St 6th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['W 53rd St 6th Ave', 'New York, NY 10019']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6388.839589432905},
#   {'id': '44SY464xDHbvOcjDzRbKkQ',
#    'alias': 'ippudo-ny-new-york-7',
#    'name': 'Ippudo NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zF3EgqHCk7zBUwD2B3WTEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ippudo-ny-new-york-7?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 9591,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73092, 'longitude': -73.99015},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '65 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 4th Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2855.84485141638},
#   {'id': 'V7lXZKBDzScDeGB8JmnzSA',
#    'alias': 'katzs-delicatessen-new-york',
#    'name': "Katz's Delicatessen",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qr7eSU6CFwRGZ7Rc-QEoTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katzs-delicatessen-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 10296,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72222, 'longitude': -73.98751},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '205 E Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 E Houston St', 'New York, NY 10003']},
#    'phone': '+12122542246',
#    'display_phone': '(212) 254-2246',
#    'distance': 1947.3740045141433},
#   {'id': 'jVncyqXwlx_D9f2xZn05tg',
#    'alias': 'the-metropolitan-museum-of-art-new-york-3',
#    'name': 'The Metropolitan Museum of Art',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IYGL2yl2Pu6P5wj3rKI_kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-metropolitan-museum-of-art-new-york-3?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 2622,
#    'categories': [{'alias': 'artmuseums', 'title': 'Art Museums'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.779254271604,
#     'longitude': -73.9628841731528},
#    'transactions': [],
#    'location': {'address1': '1000 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1000 5th Ave', 'New York, NY 10028']},
#    'phone': '+12125357710',
#    'display_phone': '(212) 535-7710',
#    'distance': 8623.2495062311},
#   {'id': 'xOw4aafJRji9XomGunlvcQ',
#    'alias': 'central-park-new-york',
#    'name': 'Central Park',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/a_T1R7oNyM-5Vtcx5ZiyPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/central-park-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 2252,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.782418740809,
#     'longitude': -73.9656022837641},
#    'transactions': [],
#    'location': {'address1': '14 E 60th St',
#     'address2': '',
#     'address3': 'Central Park Conservancy',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 E 60th St',
#      'Central Park Conservancy',
#      'New York, NY 10022']},
#    'phone': '+12123106600',
#    'display_phone': '(212) 310-6600',
#    'distance': 8893.835855571413},
#   {'id': 'jnEv25Y2DosTq2sNnvmC9g',
#    'alias': 'los-tacos-no-1-new-york',
#    'name': 'Los Tacos No.1',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FU44TYl3PzXsE06G4W5aog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 2501,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7425547, 'longitude': -74.0060838},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+12122560343',
#    'display_phone': '(212) 256-0343',
#    'distance': 4244.358699250552},
#   {'id': 'WHRHK3S1mQc3PmhwsGRvbw',
#    'alias': 'bibble-and-sip-new-york-2',
#    'name': 'Bibble & Sip',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WKYi-RRyTVlzaIV4j9430w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bibble-and-sip-new-york-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 3998,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76282, 'longitude': -73.98518},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '253 W 51st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466495116',
#    'display_phone': '(646) 649-5116',
#    'distance': 6427.9212521553545},
#   {'id': 'UA2M9QFZghe-9th2KwLoWQ',
#    'alias': 'burger-and-lobster-new-york-4',
#    'name': 'Burger & Lobster',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1rHd7F4zztAsScwzM0vDmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burger-and-lobster-new-york-4?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 4665,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74007, 'longitude': -73.99344},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '39 W 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 W 19th St', 'New York, NY 10011']},
#    'phone': '+16468337532',
#    'display_phone': '(646) 833-7532',
#    'distance': 3852.2188529432046},
#   {'id': 'veq1Bl1DW3UWMekZJUsG1Q',
#    'alias': 'gramercy-tavern-new-york',
#    'name': 'Gramercy Tavern',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1C20qnil3QUWRl3om2gOFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gramercy-tavern-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 2674,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.738527, 'longitude': -73.988417},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '42 E 20th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 E 20th St', 'New York, NY 10003']},
#    'phone': '+12124770777',
#    'display_phone': '(212) 477-0777',
#    'distance': 3711.7439058285554},
#   {'id': 'JION8hhg7q6zyayHYwhxIw',
#    'alias': 'the-high-line-new-york',
#    'name': 'The High Line',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sTIQDH9ULKhqy8mpwMPTRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-high-line-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 2197,
#    'categories': [{'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'localflavor', 'title': 'Local Flavor'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7479831752801,
#     'longitude': -74.0048906107511},
#    'transactions': [],
#    'location': {'address1': '820 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['820 Washington St', 'New York, NY 10014']},
#    'phone': '+12122069922',
#    'display_phone': '(212) 206-9922',
#    'distance': 4813.598883567381},
#   {'id': 'lWOkeS-wV4no8qqA9OwwEg',
#    'alias': 'doughnut-plant-new-york-6',
#    'name': 'Doughnut Plant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JpLMXFWyvpstlC9__dlJKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughnut-plant-new-york-6?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 3080,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7163944930004,
#     'longitude': -73.9886098620298},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '379 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['379 Grand St', 'New York, NY 10002']},
#    'phone': '+12125053700',
#    'display_phone': '(212) 505-3700',
#    'distance': 1308.3879515578776},
#   {'id': '4yPqqJDJOQX69gC66YUDkA',
#    'alias': 'peter-luger-brooklyn-2',
#    'name': 'Peter Luger',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DnReRUkXRtsmKycQEYl0pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peter-luger-brooklyn-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 5057,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.709945, 'longitude': -73.962478},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '178 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178 Broadway', 'Brooklyn, NY 11211']},
#    'phone': '+17183877400',
#    'display_phone': '(718) 387-7400',
#    'distance': 2728.016921522817},
#   {'id': 'FEVQpbOPOwAPNIgO7D3xxw',
#    'alias': 'shake-shack-new-york-2',
#    'name': 'Shake Shack',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/J0UoRJKdaMl0EPdgxYIlKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shake-shack-new-york-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 5491,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414000197233, 'longitude': -73.98815019045},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': 'Madison Square Park',
#     'address2': '',
#     'address3': 'E 23rd St & Madison Ave',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Madison Square Park',
#      'E 23rd St & Madison Ave',
#      'New York, NY 10010']},
#    'phone': '+12128896600',
#    'display_phone': '(212) 889-6600',
#    'distance': 4031.402495127816},
#   {'id': 'kViIWJFfAfWPpJOwAXBKGA',
#    'alias': 'national-september-11-memorial-museum-new-york',
#    'name': 'National September 11 Memorial Museum',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gFr_zDiUm8QJ-4gkG8v6Uw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/national-september-11-memorial-museum-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1325,
#    'categories': [{'alias': 'museums', 'title': 'Museums'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71144, 'longitude': -74.01301},
#    'transactions': [],
#    'location': {'address1': '180 Greenwich St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 Greenwich St', 'New York, NY 10007']},
#    'phone': '+12122665211',
#    'display_phone': '(212) 266-5211',
#    'distance': 1670.4082440403122},
#   {'id': 'j1S3NUrkB3BVT49n_e76NQ',
#    'alias': 'best-bagel-and-coffee-new-york',
#    'name': 'Best Bagel & Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9-8DVzhwfzFS5GUCq3O6NA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/best-bagel-and-coffee-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 2570,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7522683, 'longitude': -73.9910861},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '225 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 W 35th St', 'New York, NY 10001']},
#    'phone': '+12125644409',
#    'display_phone': '(212) 564-4409',
#    'distance': 5213.5315009761325},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'alias': 'lovemama-new-york',
#    'name': 'LoveMama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 3786,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7303859, 'longitude': -73.9860613},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '174 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122545370',
#    'display_phone': '(212) 254-5370',
#    'distance': 2858.7729410008346},
#   {'id': 'vRrVSB-LegwUwIxpkeRVtQ',
#    'alias': 'le-bernardin-new-york',
#    'name': 'Le Bernardin',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G0wZ6h5KaQG2gJkk8uOkLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-bernardin-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 2301,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.761557, 'longitude': -73.981763},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '155 W 51st St',
#     'address2': '',
#     'address3': 'The Equitable Bldg',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 W 51st St',
#      'The Equitable Bldg',
#      'New York, NY 10019']},
#    'phone': '+12125541515',
#    'display_phone': '(212) 554-1515',
#    'distance': 6328.07179784047},
#   {'id': 'nU4XBdvxDABXqZ6CnB8Dig',
#    'alias': 'clinton-street-baking-company-new-york-5',
#    'name': 'Clinton Street Baking Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DWHdizJ9bKbXN4yq6nbwAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-street-baking-company-new-york-5?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 4385,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721128, 'longitude': -73.983933},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '4 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 Clinton St', 'New York, NY 10002']},
#    'phone': '+16466026263',
#    'display_phone': '(646) 602-6263',
#    'distance': 1950.282829638887},
#   {'id': 'mvn2XFJfIPNAlvsy-arzkA',
#    'alias': 'brooklyn-bridge-brooklyn',
#    'name': 'Brooklyn Bridge',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1F5Xl0Qn5DW8nzaelPSwMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-bridge-brooklyn?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1268,
#    'categories': [{'alias': 'landmarks',
#      'title': 'Landmarks & Historical Buildings'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7059677364821,
#     'longitude': -73.9966657489186},
#    'transactions': [],
#    'location': {'address1': '334 Furman St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['334 Furman St', 'Brooklyn, NY 11201']},
#    'phone': '+17187246434',
#    'display_phone': '(718) 724-6434',
#    'distance': 208.2689719737892}],
#  'total': 24800,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %% [markdown]
# Note that location or latitute and longitude are the only required parameters. That said, you are free to pass as many parameters as you want such as:

# %%
#Note: this cell won't return a valid response unless you specify your api key
api_key = 'JmcTQw4BEwAWkl2F0tsMtuRCxbcn02U6aiu-Yu7YXzuG12_NmoFhCtB894V63kOogr6aLNAt7sv6sGPCR9xDwa89-hGBZRlUMb3tk0bEuEIlvWg6v0Vf88bpGasRXHYx'

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC',
                'term' : 'pizza',
                'limit' : 50,
                'price' : "1,2,3,4",
                'open_now' : True
            }
response = requests.get(url, headers=headers, params=url_params)
response.json()
# Out:
# {'businesses': [{'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-pizza-brooklyn-5',
#    'name': "Juliana's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1855,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7026153030093,
#     'longitude': -73.9934159993549},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 323.20506308227306},
#   {'id': 'j7K-Pevawo8PN3r0WyEE_g',
#    'alias': 'macoletta-astoria-2',
#    'name': 'Macoletta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/d36O3rx5ollsCzqYZ7Y5dA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/macoletta-astoria-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 68,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7732423, 'longitude': -73.9164153},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '28-15 24th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28-15 24th Ave', 'Astoria, NY 11102']},
#    'phone': '+17187774992',
#    'display_phone': '(718) 777-4992',
#    'distance': 9994.1309977644},
#   {'id': 'WIhm0W9197f_rRtDziq5qQ',
#    'alias': 'lombardis-pizza-new-york',
#    'name': "Lombardi's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XtCyVQ08bShUv8WdK5B-VA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 5722,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72164, 'longitude': -73.9957},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '32 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Spring St', 'New York, NY 10012']},
#    'phone': '+12129417994',
#    'display_phone': '(212) 941-7994',
#    'distance': 1804.4733931798112},
#   {'id': 'zj8Lq1T8KIC5zwFief15jg',
#    'alias': 'prince-street-pizza-new-york-2',
#    'name': 'Prince Street Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 2342,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7229087705545,
#     'longitude': -73.9944863319397},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '27 Prince St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Prince St', 'New York, NY 10012']},
#    'phone': '+12129664100',
#    'display_phone': '(212) 966-4100',
#    'distance': 1941.9638172538225},
#   {'id': 'DJSLGbSqCJ1W8ma3LFlMuw',
#    'alias': 'patzeria-perfect-pizza-new-york',
#    'name': 'Patzeria Perfect Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/w62on7rHWF6ZNTVy6M6RuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patzeria-perfect-pizza-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1497,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7594653910395,
#     'longitude': -73.9867857052142},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '231 W 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 W 46th St', 'New York, NY 10036']},
#    'phone': '+12125757646',
#    'display_phone': '(212) 575-7646',
#    'distance': 6040.018561992213},
#   {'id': 'v1DHGRNCH9247WLYoaoA9A',
#    'alias': 'l-industrie-pizzeria-brooklyn',
#    'name': "L'industrie Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SRL_RztRRUijgQwt67daGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 373,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '254 S 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#    'phone': '+17185990002',
#    'display_phone': '(718) 599-0002',
#    'distance': 3145.016041338447},
#   {'id': 'yH6t1JWcwkdWG4CS5KPvow',
#    'alias': 'adriennes-pizzabar-new-york',
#    'name': "Adrienne's Pizzabar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MOG8wpqkeYQxDslq7ospLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adriennes-pizzabar-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1481,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7043362, 'longitude': -74.0101733},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '54 Stone St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 Stone St', 'New York, NY 10004']},
#    'phone': '+12122483838',
#    'display_phone': '(212) 248-3838',
#    'distance': 1344.2671600758972},
#   {'id': '-9NO2IDCJMyNGZMAQ1-VQw',
#    'alias': 'ny-pizza-suprema-new-york',
#    'name': 'NY Pizza Suprema',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXneMuQP6pw6GemVdQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ny-pizza-suprema-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1648,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7502059936523,
#     'longitude': -73.9953231811523},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '413 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['413 8th Ave', 'New York, NY 10001']},
#    'phone': '+12125948939',
#    'display_phone': '(212) 594-8939',
#    'distance': 4977.847939164096},
#   {'id': '2ggi1luerd3Mf_C82JvCYg',
#    'alias': 'grimaldis-brooklyn-4',
#    'name': "Grimaldi's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-j-vYFV9Yx5dkS1u8-BY1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grimaldis-brooklyn-4?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 4426,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7025694629739,
#     'longitude': -73.993247611872},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188584300',
#    'display_phone': '(718) 858-4300',
#    'distance': 331.6559230633367},
#   {'id': 'uc5qQMzs96rzjK27epDCug',
#    'alias': 'joes-pizza-new-york-4',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FhbFkrh_3TrAOZvoWTyOJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 2119,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7305599, 'longitude': -74.0021299},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '7 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Carmine St', 'New York, NY 10014']},
#    'phone': '+12123661182',
#    'display_phone': '(212) 366-1182',
#    'distance': 2873.5532231399425},
#   {'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#    'alias': 'bleecker-street-pizza-new-york',
#    'name': 'Bleecker Street Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kyi2tP43S_a6s-zXD38NUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1937,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7320627016512,
#     'longitude': -74.0036552270137},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '69 7th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12129244466',
#    'display_phone': '(212) 924-4466',
#    'distance': 3072.9540450669765},
#   {'id': 'oRdM7n-AfBPBGAlH4Q0Sag',
#    'alias': 'my-pie-pizzeria-romana-new-york-2',
#    'name': 'My Pie Pizzeria Romana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vo36uaolTTa5aREAcddJnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-pie-pizzeria-romana-new-york-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 599,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7608512, 'longitude': -73.9694809},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '690 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['690 Lexington Ave', 'New York, NY 10022']},
#    'phone': '+12123171850',
#    'display_phone': '(212) 317-1850',
#    'distance': 6505.9564779774955},
#   {'id': 'ca5mjbnCm2c8E6AFIb59Rw',
#    'alias': 'luzzos-pizza-long-island-city',
#    'name': "Luzzo's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mJlzPkx_6TIadxobllDkzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luzzos-pizza-long-island-city?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 33,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7492468, 'longitude': -73.9420071},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '42-60 Crescent St',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-60 Crescent St', 'Long Island City, NY 11101']},
#    'phone': '+17184330555',
#    'display_phone': '(718) 433-0555',
#    'distance': 6551.232351374519},
#   {'id': 'c3D2ckzacnPtdGIM8tb-_w',
#    'alias': 'b-side-pizza-and-wine-bar-new-york',
#    'name': 'B Side Pizza & Wine Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m_5goJPoabzTHCyQ2qAVGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-side-pizza-and-wine-bar-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 948,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76394, 'longitude': -73.9883399},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '370 W 51st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['370 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466797225',
#    'display_phone': '(646) 679-7225',
#    'distance': 6519.850090048231},
#   {'id': 'FhXjAc6nKLf414KxYujUHw',
#    'alias': 'robertas-brooklyn-2',
#    'name': "Roberta's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xRNPKIfF2Gr02zBiBl3dSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 2544,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.705043534338, 'longitude': -73.93357123374},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '261 Moore St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#    'phone': '+17184171118',
#    'display_phone': '(718) 417-1118',
#    'distance': 5118.690592147886},
#   {'id': 'nUpA3sY5b6dynC7aj0eV6A',
#    'alias': 'rizzos-fine-pizza-new-york-4',
#    'name': "Rizzo's Fine Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/r4OPoXMhNig7p94wdW9yOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rizzos-fine-pizza-new-york-4?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 617,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720852, 'longitude': -73.984456},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '17 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Clinton St', 'New York, NY 10002']},
#    'phone': '+16464541262',
#    'display_phone': '(646) 454-1262',
#    'distance': 1903.2788345091096},
#   {'id': 'Aazjxg21VH2cncWYBAv68Q',
#    'alias': 'sottocasa-pizzeria-brooklyn-3',
#    'name': 'Sottocasa Pizzeria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jRirSN3MWw3oW33p5rncbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sottocasa-pizzeria-brooklyn-3?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 564,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.688285, 'longitude': -73.989006},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '298 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['298 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188528758',
#    'display_phone': '(718) 852-8758',
#    'distance': 1959.7870021684514},
#   {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#    'alias': 'johns-of-bleecker-street-new-york-2',
#    'name': "John's of Bleecker Street",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U9nyLF5ggN4Hh3xDaqxj0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1703,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '278 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122431680',
#    'display_phone': '(212) 243-1680',
#    'distance': 3010.899021476809},
#   {'id': 'vfYhEpp0x-DrNjC6GSJjPQ',
#    'alias': 'artichoke-basilles-pizza-new-york-2',
#    'name': "Artichoke Basille's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7F633IP6alQ6Huy7UVaY8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-new-york-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 3732,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7321124557704,
#     'longitude': -73.9839056828882},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '321 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 E 14th St', 'New York, NY 10003']},
#    'phone': '+12122282004',
#    'display_phone': '(212) 228-2004',
#    'distance': 3091.822113723405},
#   {'id': 'xRiLLXjeM2wOvVTYJH2__A',
#    'alias': 'barboncino-pizza-and-bar-brooklyn-2',
#    'name': 'Barboncino Pizza & Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/48doX4sxCRLxOl8a6AD35Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barboncino-pizza-and-bar-brooklyn-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 850,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.67209, 'longitude': -73.95731},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '781 Franklin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['781 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17184838834',
#    'display_phone': '(718) 483-8834',
#    'distance': 4848.885236425948},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OJGjehxsmb_lsxvDLg5ISQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1752,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72275, 'longitude': -73.99622},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1931.2683716470422},
#   {'id': '0UdC0VYX6aAvLiOcpR4MVQ',
#    'alias': 'joes-pizza-new-york-7',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9E2Um0ddicKyoWS-RGIXyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-7?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 724,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.733692, 'longitude': -73.988123},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '150 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 E 14th St', 'New York, NY 10003']},
#    'phone': '+12123889474',
#    'display_phone': '(212) 388-9474',
#    'distance': 3183.688184836435},
#   {'id': '7qYeyW9_dxnbaBCFUXGk_A',
#    'alias': 'stage-door-pizza-new-york',
#    'name': 'Stage Door Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G_R4NqV4mPa5ffR7kmuB9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stage-door-pizza-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 220,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7120047333763,
#     'longitude': -74.0096561511938},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '26 Vesey St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 Vesey St', 'New York, NY 10007']},
#    'phone': '+12125666222',
#    'display_phone': '(212) 566-6222',
#    'distance': 1486.2421351984565},
#   {'id': 'xrgzB0pvsxeGEIboE6I2gg',
#    'alias': 'patsys-pizzeria-brooklyn-2',
#    'name': "Patsy's Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1n5xL5ojLR-_zseirQKaMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patsys-pizzeria-brooklyn-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 441,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6818695, 'longitude': -73.976181},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '450 Dean St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['450 Dean St', 'Brooklyn, NY 11217']},
#    'phone': '+17186222268',
#    'display_phone': '(718) 622-2268',
#    'distance': 3034.9893998767334},
#   {'id': 'TmPsmR6rnId2Rxg1al1-cA',
#    'alias': 'oath-pizza-east-67th-street-new-york',
#    'name': 'Oath Pizza - East 67th Street',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jhrNupIvSXnjaKEbHLt9iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oath-pizza-east-67th-street-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 56,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7664835, 'longitude': -73.9633564},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1142 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10065',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1142 3rd Ave', 'New York, NY 10065']},
#    'phone': '+12129884300',
#    'display_phone': '(212) 988-4300',
#    'distance': 7270.493379689565},
#   {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#    'alias': 'joes-pizza-new-york-148',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5P5i2QZhxCen55PNdU_TTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 446,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7545841255557,
#     'longitude': -73.9870039190341},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1435 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1435 Broadway', 'New York, NY 10018']},
#    'phone': '+16465594878',
#    'display_phone': '(646) 559-4878',
#    'distance': 5498.444221355099},
#   {'id': 'FKzpfWUpyupl4q74Jt8fTA',
#    'alias': 'don-antonio-new-york-3',
#    'name': 'Don Antonio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kwv16TeExWDWWLLbCNq7Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-antonio-new-york-3?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1244,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.762711, 'longitude': -73.986708},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '309 W 50th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['309 W 50th St', 'New York, NY 10019']},
#    'phone': '+16467191043',
#    'display_phone': '(646) 719-1043',
#    'distance': 6399.689323736132},
#   {'id': 'H8qcX7MNNnC1bqE0LnIhKg',
#    'alias': 'simò-pizza-new-york-4',
#    'name': 'SIMÒ PIZZA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kDmxLQ2dweGswPZ6Bm1jMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sim%C3%B2-pizza-new-york-4?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 63,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7392597584612,
#     'longitude': -74.0088130692187},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '90-92 Gansevoort St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90-92 Gansevoort St', 'New York, NY 10014']},
#    'phone': '+12124622703',
#    'display_phone': '(212) 462-2703',
#    'distance': 3954.1313238707344},
#   {'id': 'kVrTff8uDMSBAaceBwQ7dg',
#    'alias': 'saluggis-new-york',
#    'name': "Saluggi's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P_NI4AhmWBAi4c33PViGMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saluggis-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 536,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720104, 'longitude': -74.003578},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '325 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['325 Church St', 'New York, NY 10013']},
#    'phone': '+12122267900',
#    'display_phone': '(212) 226-7900',
#    'distance': 1808.5885826304711},
#   {'id': 'wTNUUoYUl3gox-gUAZ9bAA',
#    'alias': 'peppinos-brick-oven-pizza-and-restaurant-brooklyn-2',
#    'name': "Peppino's Brick Oven Pizza & Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PCmB_Hk-usk05-PUXJvSqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peppinos-brick-oven-pizza-and-restaurant-brooklyn-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 372,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.668221, 'longitude': -73.986936},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '469 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['469 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187687244',
#    'display_phone': '(718) 768-7244',
#    'distance': 4185.328288702886},
#   {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#    'alias': 'joes-pizza-brooklyn-8',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jssK0tlhhXjUztbPnA3OEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 223,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71691, 'longitude': -73.958987},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '216 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17183882216',
#    'display_phone': '(718) 388-2216',
#    'distance': 3239.2966565668607},
#   {'id': 'IZ9-5z45wc3Oh_jlnX_Kcg',
#    'alias': 'giuseppinas-brooklyn',
#    'name': "Giuseppina's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3A6Z_rhL9FPuHMZYlRXU4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giuseppinas-brooklyn?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 278,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6603430973463,
#     'longitude': -73.9907741546631},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '691 6th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['691 6th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184995052',
#    'display_phone': '(718) 499-5052',
#    'distance': 5023.85312943866},
#   {'id': 'tRIHhPKryUZ56SfIz6mLiA',
#    'alias': 'angelos-coal-oven-pizzeria-new-york',
#    'name': "Angelo's Coal Oven Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Xp-OU4KHYapv_vEPm_YQ7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/angelos-coal-oven-pizzeria-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 732,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76492, 'longitude': -73.97794},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '117 W 57th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 W 57th St', 'New York, NY 10019']},
#    'phone': '+12123334333',
#    'display_phone': '(212) 333-4333',
#    'distance': 6753.601098536139},
#   {'id': 'lxPVSGnZ7YTiO5OGrqBS8Q',
#    'alias': 'vinnies-pizzeria-brooklyn',
#    'name': "Vinnie's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T35Yd0xRbxwjaFJJ-CjiBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinnies-pizzeria-brooklyn?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 605,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718925, 'longitude': -73.956878},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '148 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['148 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187827078',
#    'display_phone': '(718) 782-7078',
#    'distance': 3489.0079917146263},
#   {'id': 'J38XGzriEkMsDfCMt6et_g',
#    'alias': 'vezzo-new-york-2',
#    'name': 'Vezzo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zEbvF-vMabMmovicwAoCSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vezzo-new-york-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1153,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7445, 'longitude': -73.98139},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '178 Lexington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178 Lexington Ave', 'New York, NY 10016']},
#    'phone': '+12128398300',
#    'display_phone': '(212) 839-8300',
#    'distance': 4477.207399502018},
#   {'id': 'Cf_XvhoRJj9Ku0glKGu7aQ',
#    'alias': 'lucia-pizza-flushing',
#    'name': 'Lucia Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8dYTxzQTLL62F_DyasuqQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucia-pizza-flushing?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 450,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76032, 'longitude': -73.82813},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '136-55 Roosevelt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136-55 Roosevelt Ave', 'Flushing, NY 11354']},
#    'phone': '+17184451313',
#    'display_phone': '(718) 445-1313',
#    'distance': 15268.027801746888},
#   {'id': 'xsQTIeq-WLkp4ParkTQpMQ',
#    'alias': 'pizzarte-new-york',
#    'name': 'PizzArte',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8EwhNCxBMkLlGV-PJ-macw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzarte-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 941,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7629335072372,
#     'longitude': -73.9776668697596},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '69 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 W 55th St', 'New York, NY 10019']},
#    'phone': '+12122473936',
#    'display_phone': '(212) 247-3936',
#    'distance': 6544.13958857817},
#   {'id': 'zmIrZgWhRdyRMrnEs9D3KA',
#    'alias': 'la-margarita-pizza-new-york',
#    'name': 'La Margarita Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7NH6z9iOZETlq8AKFwkcyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-margarita-pizza-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 252,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7215392420787,
#     'longitude': -73.9876275438289},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '168 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168 Ludlow St', 'New York, NY 10002']},
#    'phone': '+19172614983',
#    'display_phone': '(917) 261-4983',
#    'distance': 1875.7222956933838},
#   {'id': 'MHbxF-ZS918-ZoXKQPBEyg',
#    'alias': 'sotto-le-stelle-sunnyside',
#    'name': 'Sotto Le Stelle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XXa_1w-s3LEml0UyNRu8nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sotto-le-stelle-sunnyside?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 140,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74371, 'longitude': -73.92008},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '44-07 Queens Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['44-07 Queens Blvd', 'Sunnyside, NY 11104']},
#    'phone': '+17186852086',
#    'display_phone': '(718) 685-2086',
#    'distance': 7563.522673487805},
#   {'id': 'd7Asc4q2ImoPlA_BhfroTQ',
#    'alias': 'kesté-pizza-and-vino-new-york-2',
#    'name': 'Kesté Pizza & Vino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QmCGZCd9KsysWQddAnHTdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kest%C3%A9-pizza-and-vino-new-york-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 1307,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73154, 'longitude': -74.00293},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '271 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['271 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122431500',
#    'display_phone': '(212) 243-1500',
#    'distance': 2991.8818535500936},
#   {'id': 'vyoA8dxwScuMV_AsTcjQcg',
#    'alias': 'l-and-b-spumoni-gardens-brooklyn',
#    'name': 'L & B Spumoni Gardens',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BrTci9PjIwi7V1vkbgkdqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-and-b-spumoni-gardens-brooklyn?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 3256,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.594715, 'longitude': -73.981316},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2725 86th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11223',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2725 86th St', 'Brooklyn, NY 11223']},
#    'phone': '+17184491230',
#    'display_phone': '(718) 449-1230',
#    'distance': 12361.163422806636},
#   {'id': 'EsHcyOLHaK76bQuU7bwiTw',
#    'alias': 'tonys-pizzeria-and-restaurant-brooklyn-3',
#    'name': 'Tonys Pizzeria & Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wEPzpmEQ2Hd-WkeKUGe1Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonys-pizzeria-and-restaurant-brooklyn-3?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 249,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.699286, 'longitude': -73.918724},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '443 Knickerbocker Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['443 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17184559664',
#    'display_phone': '(718) 455-9664',
#    'distance': 6407.0089037876505},
#   {'id': 'i9UMc9gLeORtCLd-OoGgYg',
#    'alias': 'lions-and-tigers-and-squares-detroit-pizza-new-york',
#    'name': 'Lions & Tigers & Squares Detroit Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qBDE8a72KBxn54RijWyx0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lions-and-tigers-and-squares-detroit-pizza-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 193,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74506, 'longitude': -73.99834},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '268 W 23rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['268 W 23rd St', 'New York, NY 10011']},
#    'phone': '+19172616772',
#    'display_phone': '(917) 261-6772',
#    'distance': 4417.8756785431715},
#   {'id': 'JFw_Zj4CFTJbTPKJdPQ_Gw',
#    'alias': 'freddie-and-peppers-new-york',
#    'name': "Freddie & Pepper's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/llep60r8kE65uo1ZYwkXUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freddie-and-peppers-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 413,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.779999, 'longitude': -73.980301},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '303 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['303 Amsterdam Ave', 'New York, NY 10023']},
#    'phone': '+12127992378',
#    'display_phone': '(212) 799-2378',
#    'distance': 8373.421944862941},
#   {'id': 'S4uozcDEieoaXxIJ6TsUoQ',
#    'alias': 'dellaroccos-brick-oven-pizza-brooklyn',
#    'name': "Dellarocco's Brick Oven Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RGsip2vQXryVUbOrXfYBkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dellaroccos-brick-oven-pizza-brooklyn?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 221,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6950309, 'longitude': -73.9961252},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '214 Hicks St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Hicks St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581010',
#    'display_phone': '(718) 858-1010',
#    'distance': 1170.2700329972115},
#   {'id': 'atbANdSznV29GI066I2Ijw',
#    'alias': 'champion-pizza-new-york-6',
#    'name': 'Champion Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SV5N-uxEa1tHUXYLAi43xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/champion-pizza-new-york-6?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 228,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7215270996094,
#     'longitude': -73.9970855712891},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '17 Cleveland Pl',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Cleveland Pl', 'New York, NY 10012']},
#    'phone': '+12122263777',
#    'display_phone': '(212) 226-3777',
#    'distance': 1801.4764439408825},
#   {'id': 'JnjmCHUQBEfpF7vSKnxU7g',
#    'alias': 'sunnyside-pizza-sunnyside-2',
#    'name': 'Sunnyside Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cRNfAt8I8H4R1x_vz5FbbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunnyside-pizza-sunnyside-2?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 361,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7438380472824,
#     'longitude': -73.9241266284942},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4001 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4001 Queens Blvd', 'Sunnyside, NY 11104']},
#    'phone': '+17184334040',
#    'display_phone': '(718) 433-4040',
#    'distance': 7292.992783704455},
#   {'id': '2xQmBB6w-W6lxiex80fA9A',
#    'alias': 'luigis-pizzeria-brooklyn-4',
#    'name': "Luigi's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QgrEW-SMfez8OkMHlgg-Rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luigis-pizzeria-brooklyn-4?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 225,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6897, 'longitude': -73.965369},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '326 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['326 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187832430',
#    'display_phone': '(718) 783-2430',
#    'distance': 3001.8318150390764},
#   {'id': 'Z67mgMkN3RfdPEX5mXsyYA',
#    'alias': 'piacere-new-york',
#    'name': 'Piacere',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AM-GqB2MkX92CDifh8msIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piacere-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 642,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7196979, 'longitude': -73.9951175},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '351 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['351 Broome St', 'New York, NY 10013']},
#    'phone': '+12122194080',
#    'display_phone': '(212) 219-4080',
#    'distance': 1586.3855179286054},
#   {'id': 'SpyQHasbnU5YkOR6PI4sNQ',
#    'alias': 'margherita-nyc-new-york',
#    'name': 'Margherita NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GOUXE4GPpJ-yDw3CQcSysg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/margherita-nyc-new-york?adjust_creative=4a1Th_CK66VwxOJRBiL9Ug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4a1Th_CK66VwxOJRBiL9Ug',
#    'review_count': 259,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7189865112305,
#     'longitude': -73.9969329833984},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '197 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['197 Grand St', 'New York, NY 10013']},
#    'phone': '+12122268391',
#    'display_phone': '(212) 226-8391',
#    'distance': 1531.530627996726}],
#  'total': 6800,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %% [markdown]
# The final important note is how some of the parameters have alternative formats. For example, limit is an integer and open_now is a boolean according to the documentation. Following these conventions is essential to receiving valid responses.

# %% [markdown]
# # Summary
#
# Congratulations! Not only have you seen an API now, you've also practiced sifting through the documentation. The last piece in working with APIs is developing a more solid understanding of JSON files; the data format typically returned by modern APIs.
